# %% [markdown]
# # Pandas
#
# Sebuah toolbox untuk pengolahan data yang besar

# %%
import pandas as pd

# %% [markdown]
# ## Data assignment

# %%
negara = {
    "country": ["Brazil", "Russia", "India", "China", "South Africa"],
    "capital": ["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"],
    "area": [8.516, 17.10, 3.286, 9.597, 1.221],
    "population": [200.4, 143.5, 1252, 1357, 52.98] 
}

# %%
negara_df = pd.DataFrame(negara)

# %%
negara_df
# Out:
#      area    capital       country  population
# 0   8.516   Brasilia        Brazil      200.40
# 1  17.100     Moscow        Russia      143.50
# 2   3.286  New Delhi         India     1252.00
# 3   9.597    Beijing         China     1357.00
# 4   1.221   Pretoria  South Africa       52.98

# %%
negara_df.index = ["BR", "RU", "IN", "CH", "SA"]
negara_df
# Out:
#       area    capital       country  population
# BR   8.516   Brasilia        Brazil      200.40
# RU  17.100     Moscow        Russia      143.50
# IN   3.286  New Delhi         India     1252.00
# CH   9.597    Beijing         China     1357.00
# SA   1.221   Pretoria  South Africa       52.98

# %%
negara_df = pd.DataFrame(negara, index=["BR", "RU", "IN", "CH", "SA"])
negara_df
# Out:
#       area    capital       country  population
# BR   8.516   Brasilia        Brazil      200.40
# RU  17.100     Moscow        Russia      143.50
# IN   3.286  New Delhi         India     1252.00
# CH   9.597    Beijing         China     1357.00
# SA   1.221   Pretoria  South Africa       52.98

# %% [markdown]
# ## Files

# %%
df = pd.read_csv('negara.csv')

# %%
df
# Out:
#   Unnamed: 0       country    capital    area  population
# 0         BR        Brazil   Brasilia   8.516      200.40
# 1         RU        Russia     Moscow  17.100      143.50
# 2         IN         India  New Delhi   3.286     1252.00
# 3         CH         China    Beijing   9.597     1357.00
# 4         SA  South Africa   Pretoria   1.221       52.98

# %%
df = pd.read_csv('negara.csv', index_col=0)
df
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %% [markdown]
# ## Pengolahan Data

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (5, 4)

# %%
df.columns
# Out:
# Index(['country', 'capital', 'area', 'population'], dtype='object')

# %%
df.index
# Out:
# Index(['BR', 'RU', 'IN', 'CH', 'SA'], dtype='object')

# %%
type(df.index)
# Out:
# pandas.core.indexes.base.Index

# %%
df = df.sort_values('area', ascending=True)
df
# Out:
#          country    capital    area  population
# SA  South Africa   Pretoria   1.221       52.98
# IN         India  New Delhi   3.286     1252.00
# BR        Brazil   Brasilia   8.516      200.40
# CH         China    Beijing   9.597     1357.00
# RU        Russia     Moscow  17.100      143.50

# %%
df = df.sort_values('area', ascending=False)
df
# Out:
#          country    capital    area  population
# RU        Russia     Moscow  17.100      143.50
# CH         China    Beijing   9.597     1357.00
# BR        Brazil   Brasilia   8.516      200.40
# IN         India  New Delhi   3.286     1252.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
df = df.sort_index()
df
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# CH         China    Beijing   9.597     1357.00
# IN         India  New Delhi   3.286     1252.00
# RU        Russia     Moscow  17.100      143.50
# SA  South Africa   Pretoria   1.221       52.98

# %%
df = df.sort_index(ascending=False)
df
# Out:
#          country    capital    area  population
# SA  South Africa   Pretoria   1.221       52.98
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# BR        Brazil   Brasilia   8.516      200.40

# %%
df = df.sort_index()
df
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# CH         China    Beijing   9.597     1357.00
# IN         India  New Delhi   3.286     1252.00
# RU        Russia     Moscow  17.100      143.50
# SA  South Africa   Pretoria   1.221       52.98

# %%
print( type(df['country']) )
df['country']
# Out:
# <class 'pandas.core.series.Series'>
# BR          Brazil
# CH           China
# IN           India
# RU          Russia
# SA    South Africa
# Name: country, dtype: object

# %%
print( type(df[['country']]) )
df[['country']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#          country
# BR        Brazil
# CH         China
# IN         India
# RU        Russia
# SA  South Africa

# %%
df[['country','capital']]
# Out:
#          country    capital
# BR        Brazil   Brasilia
# CH         China    Beijing
# IN         India  New Delhi
# RU        Russia     Moscow
# SA  South Africa   Pretoria

# %%
df[1:4]
# Out:
#    country    capital    area  population
# CH   China    Beijing   9.597      1357.0
# IN   India  New Delhi   3.286      1252.0
# RU  Russia     Moscow  17.100       143.5

# %% [markdown]
# ## Menggunakan loc

# %%
df.loc['RU']
# Out:
# country       Russia
# capital       Moscow
# area            17.1
# population     143.5
# Name: RU, dtype: object

# %%
df.loc[['RU']]
# Out:
#    country capital  area  population
# RU  Russia  Moscow  17.1       143.5

# %%
df.loc[['RU','IN','CH']]
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %%
df.loc[["RU", "IN", "CH"], ["country", "capital"]]
# Out:
#    country    capital
# RU  Russia     Moscow
# IN   India  New Delhi
# CH   China    Beijing

# %%
df.loc[:, ["country","capital"]]
# Out:
#          country    capital
# BR        Brazil   Brasilia
# CH         China    Beijing
# IN         India  New Delhi
# RU        Russia     Moscow
# SA  South Africa   Pretoria

# %% [markdown]
# ## Menggunakan iloc

# %%
df
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# CH         China    Beijing   9.597     1357.00
# IN         India  New Delhi   3.286     1252.00
# RU        Russia     Moscow  17.100      143.50
# SA  South Africa   Pretoria   1.221       52.98

# %%
df.loc['CH']
# Out:
# country         China
# capital       Beijing
# area            9.597
# population       1357
# Name: CH, dtype: object

# %%
df.iloc[1]
# Out:
# country         China
# capital       Beijing
# area            9.597
# population       1357
# Name: CH, dtype: object

# %%
df.loc[['CH','IN','RU']]
# Out:
#    country    capital    area  population
# CH   China    Beijing   9.597      1357.0
# IN   India  New Delhi   3.286      1252.0
# RU  Russia     Moscow  17.100       143.5

# %%
df.iloc[[1,2,3]]
# Out:
#    country    capital    area  population
# CH   China    Beijing   9.597      1357.0
# IN   India  New Delhi   3.286      1252.0
# RU  Russia     Moscow  17.100       143.5

# %%
df.loc[["RU", "IN", "CH"], ["country", "capital"]]
# Out:
#    country    capital
# RU  Russia     Moscow
# IN   India  New Delhi
# CH   China    Beijing

# %%
df.iloc[[1,2,3], [0, 1]]
# Out:
#    country    capital
# CH   China    Beijing
# IN   India  New Delhi
# RU  Russia     Moscow

# %%
df.loc[:, ["country", "capital"]]
# Out:
#          country    capital
# BR        Brazil   Brasilia
# CH         China    Beijing
# IN         India  New Delhi
# RU        Russia     Moscow
# SA  South Africa   Pretoria

# %%
df.iloc[:, [0, 1]]
# Out:
#          country    capital
# BR        Brazil   Brasilia
# CH         China    Beijing
# IN         India  New Delhi
# RU        Russia     Moscow
# SA  South Africa   Pretoria

# %% [markdown]
# ## Loop

# %%
for sesuatu in negara:
    print(sesuatu)
# Out:
# country
# capital
# area
# population

# %%
for label, baris in df.iterrows():
    print('Label: ' + label)
    print(baris)
    print()
# Out:
# Label: BR
# country         Brazil
# capital       Brasilia
# area             8.516
# population       200.4
# Name: BR, dtype: object
#
# Label: CH
# country         China
# capital       Beijing
# area            9.597
# population       1357
# Name: CH, dtype: object
#
# Label: IN
# country           India
# capital       New Delhi
# area              3.286
# population         1252
# Name: IN, dtype: object
#
# Label: RU
# country       Russia
# capital       Moscow
# area            17.1
# population     143.5
# Name: RU, dtype: object
#
# Label: SA
# country       South Africa
# capital           Pretoria
# area                 1.221
# population           52.98
# Name: SA, dtype: object

# %%
for label, baris in df.iterrows():
    print(label + ": " + baris['capital'])
# Out:
# BR: Brasilia
# CH: Beijing
# IN: New Delhi
# RU: Moscow
# SA: Pretoria

# %%
df
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# CH         China    Beijing   9.597     1357.00
# IN         India  New Delhi   3.286     1252.00
# RU        Russia     Moscow  17.100      143.50
# SA  South Africa   Pretoria   1.221       52.98

# %%
for label, baris in df.iterrows():
    df.loc[label, "panjang_nama"] = len( baris["country"] )
    
df
# Out:
#          country    capital    area  population  panjang_nama
# BR        Brazil   Brasilia   8.516      200.40           6.0
# CH         China    Beijing   9.597     1357.00           5.0
# IN         India  New Delhi   3.286     1252.00           5.0
# RU        Russia     Moscow  17.100      143.50           6.0
# SA  South Africa   Pretoria   1.221       52.98          12.0

# %%
df['panjang_nama2'] = df['country'].apply(len)
df
# Out:
#          country    capital    area  population  panjang_nama  panjang_nama2
# BR        Brazil   Brasilia   8.516      200.40           6.0              6
# CH         China    Beijing   9.597     1357.00           5.0              5
# IN         India  New Delhi   3.286     1252.00           5.0              5
# RU        Russia     Moscow  17.100      143.50           6.0              6
# SA  South Africa   Pretoria   1.221       52.98          12.0             12

# %%
del df['panjang_nama']
df
# Out:
#          country    capital    area  population  panjang_nama2
# BR        Brazil   Brasilia   8.516      200.40              6
# CH         China    Beijing   9.597     1357.00              5
# IN         India  New Delhi   3.286     1252.00              5
# RU        Russia     Moscow  17.100      143.50              6
# SA  South Africa   Pretoria   1.221       52.98             12

# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as plt
# from matplotlib import pyplot as plt

# => plt.plot()

# import matplotlib.pyplot => matplotlib.pyplot.plot()
# from matplotlib import pyplot => pyplot.plot()

# %matplotlib inline

# %%
plt.plot(df.index, df['area'])

# %%
plt.scatter(df.index, df['area'])

# %% [markdown]
# ## Plotting data yang banyak

# %%
import numpy as np

# %%
year = [1950,
 1951,
 1952,
 1953,
 1954,
 1955,
 1956,
 1957,
 1958,
 1959,
 1960,
 1961,
 1962,
 1963,
 1964,
 1965,
 1966,
 1967,
 1968,
 1969,
 1970,
 1971,
 1972,
 1973,
 1974,
 1975,
 1976,
 1977,
 1978,
 1979,
 1980,
 1981,
 1982,
 1983,
 1984,
 1985,
 1986,
 1987,
 1988,
 1989,
 1990,
 1991,
 1992,
 1993,
 1994,
 1995,
 1996,
 1997,
 1998,
 1999,
 2000,
 2001,
 2002,
 2003,
 2004,
 2005,
 2006,
 2007,
 2008,
 2009,
 2010,
 2011,
 2012,
 2013,
 2014,
 2015,
 2016,
 2017,
 2018,
 2019,
 2020,
 2021,
 2022,
 2023,
 2024,
 2025,
 2026,
 2027,
 2028,
 2029,
 2030,
 2031,
 2032,
 2033,
 2034,
 2035,
 2036,
 2037,
 2038,
 2039,
 2040,
 2041,
 2042,
 2043,
 2044,
 2045,
 2046,
 2047,
 2048,
 2049,
 2050,
 2051,
 2052,
 2053,
 2054,
 2055,
 2056,
 2057,
 2058,
 2059,
 2060,
 2061,
 2062,
 2063,
 2064,
 2065,
 2066,
 2067,
 2068,
 2069,
 2070,
 2071,
 2072,
 2073,
 2074,
 2075,
 2076,
 2077,
 2078,
 2079,
 2080,
 2081,
 2082,
 2083,
 2084,
 2085,
 2086,
 2087,
 2088,
 2089,
 2090,
 2091,
 2092,
 2093,
 2094,
 2095,
 2096,
 2097,
 2098,
 2099,
 2100]

# %%
pop = [2.53,
 2.57,
 2.62,
 2.67,
 2.71,
 2.76,
 2.81,
 2.86,
 2.92,
 2.97,
 3.03,
 3.08,
 3.14,
 3.2,
 3.26,
 3.33,
 3.4,
 3.47,
 3.54,
 3.62,
 3.69,
 3.77,
 3.84,
 3.92,
 4.0,
 4.07,
 4.15,
 4.22,
 4.3,
 4.37,
 4.45,
 4.53,
 4.61,
 4.69,
 4.78,
 4.86,
 4.95,
 5.05,
 5.14,
 5.23,
 5.32,
 5.41,
 5.49,
 5.58,
 5.66,
 5.74,
 5.82,
 5.9,
 5.98,
 6.05,
 6.13,
 6.2,
 6.28,
 6.36,
 6.44,
 6.51,
 6.59,
 6.67,
 6.75,
 6.83,
 6.92,
 7.0,
 7.08,
 7.16,
 7.24,
 7.32,
 7.4,
 7.48,
 7.56,
 7.64,
 7.72,
 7.79,
 7.87,
 7.94,
 8.01,
 8.08,
 8.15,
 8.22,
 8.29,
 8.36,
 8.42,
 8.49,
 8.56,
 8.62,
 8.68,
 8.74,
 8.8,
 8.86,
 8.92,
 8.98,
 9.04,
 9.09,
 9.15,
 9.2,
 9.26,
 9.31,
 9.36,
 9.41,
 9.46,
 9.5,
 9.55,
 9.6,
 9.64,
 9.68,
 9.73,
 9.77,
 9.81,
 9.85,
 9.88,
 9.92,
 9.96,
 9.99,
 10.03,
 10.06,
 10.09,
 10.13,
 10.16,
 10.19,
 10.22,
 10.25,
 10.28,
 10.31,
 10.33,
 10.36,
 10.38,
 10.41,
 10.43,
 10.46,
 10.48,
 10.5,
 10.52,
 10.55,
 10.57,
 10.59,
 10.61,
 10.63,
 10.65,
 10.66,
 10.68,
 10.7,
 10.72,
 10.73,
 10.75,
 10.77,
 10.78,
 10.79,
 10.81,
 10.82,
 10.83,
 10.84,
 10.85]

# %%
populasi = pd.DataFrame({
    'pop':pop
}, index=year)

# %%
populasi
# Out:
#         pop
# 1950   2.53
# 1951   2.57
# 1952   2.62
# 1953   2.67
# 1954   2.71
# 1955   2.76
# 1956   2.81
# 1957   2.86
# 1958   2.92
# 1959   2.97
# 1960   3.03
# 1961   3.08
# 1962   3.14
# 1963   3.20
# 1964   3.26
# 1965   3.33
# 1966   3.40
# 1967   3.47
# 1968   3.54
# 1969   3.62
# 1970   3.69
# 1971   3.77
# 1972   3.84
# 1973   3.92
# 1974   4.00
# 1975   4.07
# 1976   4.15
# 1977   4.22
# 1978   4.30
# 1979   4.37
# ...     ...
# 2071  10.31
# 2072  10.33
# 2073  10.36
# 2074  10.38
# 2075  10.41
# 2076  10.43
# 2077  10.46
# 2078  10.48
# 2079  10.50
# 2080  10.52
# 2081  10.55
# 2082  10.57
# 2083  10.59
# 2084  10.61
# 2085  10.63
# 2086  10.65
# 2087  10.66
# 2088  10.68
# 2089  10.70
# 2090  10.72
# 2091  10.73
# 2092  10.75
# 2093  10.77
# 2094  10.78
# 2095  10.79
# 2096  10.81
# 2097  10.82
# 2098  10.83
# 2099  10.84
# 2100  10.85
#
# [151 rows x 1 columns]

# %%
plt.plot(year, pop)

# %%
plt.plot(populasi)

# %%
plt.plot(populasi)
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('World Population Projections')
# Out:
# Text(0.5,1,'World Population Projections')

# %%
plt.plot(populasi)
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('World Population Projections')
plt.yticks([0, 2, 4, 6, 8, 10])
# Out:
# ([<matplotlib.axis.YTick at 0x7f65b0899390>,
# ...
#  <a list of 6 Text yticklabel objects>)

# %%
plt.plot(populasi)
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('World Population Projections')
plt.yticks([0, 2, 4, 6, 8, 10],
['0', '2B', '4B', '6B', '8B', '10B'])
# Out:
# ([<matplotlib.axis.YTick at 0x7f65b10b4be0>,
# ...
#  <a list of 6 Text yticklabel objects>)

# %%
plt.plot(populasi)
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('World Population Projections')
plt.yticks([0, 2, 4, 6, 8, 10],
['0', '2B', '4B', '6B', '8B', '10B'])
plt.xticks([1900, 2000, 2100])
# Out:
# ([<matplotlib.axis.XTick at 0x7f65b10a02e8>,
# ...
#  <a list of 3 Text xticklabel objects>)

# %% [markdown]
# ## Membuat plot lebih menarik
# https://matplotlib.org/users/style_sheets.html

# %%
plt.style.use('fivethirtyeight')
plt.plot(populasi)

# %%
plt.style.use('seaborn')
plt.plot(populasi)

# %%
populasi['pop'].plot()

# %% [markdown]
# ## Banyak Jenis Data

# %%
AAPL = pd.read_csv('aapl.csv', index_col=0, parse_dates=True)
AAPL
# Out:
#               Open    High     Low   Close    Volume  Adj Close
# Date
# 1984-09-07   26.50   26.87   26.25   26.50   2981600       3.02
# 1984-09-10   26.50   26.62   25.87   26.37   2346400       3.01
# 1984-09-11   26.62   27.37   26.62   26.87   5444000       3.07
# 1984-09-12   26.87   27.00   26.12   26.12   4773600       2.98
# 1984-09-13   27.50   27.62   27.50   27.50   7429600       3.14
# 1984-09-14   27.62   28.50   27.62   27.87   8826400       3.18
# 1984-09-17   28.62   29.00   28.62   28.62   6886400       3.27
# 1984-09-18   28.62   28.87   27.62   27.62   3495200       3.15
# 1984-09-19   27.62   27.87   27.00   27.00   3816000       3.08
# 1984-09-20   27.12   27.37   27.12   27.12   2387200       3.09
# 1984-09-21   27.12   27.87   26.50   26.87   3591200       3.07
# 1984-09-24   26.87   27.00   26.62   26.62   2833600       3.04
# 1984-09-25   26.50   26.50   26.12   26.12   5977600       2.98
# 1984-09-26   26.12   27.25   25.75   25.75   3987200       2.94
# ...

# %%
plt.plot(AAPL)

# %%
AAPL.plot()

# %%
AAPL.plot()
plt.yscale('log')

# %%
AAPL['Open'].plot(color='b', style='-', legend=True)
AAPL['Close'].plot(color='r', style='.', legend=True)
plt.axis(('2001', '2002', 0, 30))
# Out:
# ('2001', '2002', 0, 30)

# %%
AAPL.loc['2001':'2004',['Open', 'Close', 'High','Low']].plot()

# %%
AAPL.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  6081.000000  6081.000000  6081.000000  6081.000000  6.081000e+03
# mean     46.823511    47.681506    45.913595    46.798619  1.363986e+07
# std      33.993517    34.578077    33.273106    33.947235  1.352107e+07
# min      12.880000    13.190000    12.720000    12.940000  8.880000e+04
# 25%      24.730000    25.010000    24.200000    24.690000  5.530000e+06
# 50%      38.250000    38.880000    37.460000    38.130000  8.976400e+06
# 75%      53.500000    54.550000    52.500000    53.610000  1.631920e+07
# max     200.590000   202.960000   197.800000   199.830000  2.650690e+08
#
#          Adj Close
# count  6081.000000
# mean     23.529794
# std      37.375601
# min       1.650000
# 25%       7.380000
# 50%       9.910000
# 75%      14.360000
# max     199.830000
